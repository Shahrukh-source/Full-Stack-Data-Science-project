# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\shahrukh khan\anaconda3\lib\site-packages (8.0.29)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: protobuf>=3.0.0 in c:\users\shahrukh khan\anaconda3\lib\site-packages (from mysql-connector-python) (3.20.1)

# %%
import mysql.connector as connection

try:
    mydb = connection.connect(host= "localhost", user= "root",passwd="srk123",use_pure= True)
    #chech if the connection is established
    
    query = "SHOW DATABASES"
    
    cursor = mydb.cursor() #create a curser to execute queries
    cursor.execute(query)
    print(cursor.fetchall())
    
except Exception as e:
        mydb.close()
        print(str(e))
# Out:
# [('amazon',), ('breast_cancer_db',), ('company',), ('information_schema',), ('intro_sql',), ('join_sql',), ('lic',), ('my_sqlsql',), ('mysql',), ('new_telco',), ('performance_schema',), ('srkkhansahab',), ('student',), ('sys',), ('titanic',), ('zomato',)]

# %%
import mysql.connector as connection

# %%
conn = connection.connect(host= "localhost", user= "root",passwd="srk123",use_pure= True)

# %%
cur = conn.cursor()

# %%
cur.execute("create database LIC")
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# C:\Users\SHAHRU~1\AppData\Local\Temp/ipykernel_14636/2275653119.py in <module>
# ----> 1 cur.execute("create database LIC")
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     570
#     571         try:
# --> 572             self._handle_result(self._connection.cmd_query(stmt))
#     573         except errors.InterfaceError:
#     574             if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     920         query = bytes(packet)
#     921         try:
# --> 922             result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     923         except errors.ProgrammingError as err:
#     924             if err.errno == 3948 and \
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in _handle_result(self, packet)
#     730             return self._handle_eof(packet)
#     731         elif packet[4] == 255:
# --> 732             raise errors.get_exception(packet)
#     733
#     734         # We have a text result set
#
# DatabaseError: 1007 (HY000): Can't create database 'lic'; database exists

# %%
cur.execute("show databases")

# %%
res = cur.fetchall()

# %%
res

# %%
for i in res:
    print(i[0])
# Out:
# amazon
# breast_cancer_db
# company
# information_schema
# intro_sql
# join_sql
# lic
# my_sqlsql
# mysql
# new_telco
# performance_schema
# srkkhansahab
# student
# sys
# titanic
# zomato

# %%
import mysql.connector as connection

try:
    mydb = connection.connect(host= "localhost", user= "root",passwd="srk123",use_pure= True)
    #chech if the connection is established
    print(mydb.is_connected())
    
    query = "create database  LIC ;"
    cursor= mydb.cursor() #create a cursor to execute  queries
    cursor.execute(query)
    print("(Database Created!!")
    mydb.close()
except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# True
# 1007 (HY000): Can't create database 'lic'; database exists

# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\shahrukh khan\anaconda3\lib\site-packages (8.0.29)
# Requirement already satisfied: protobuf>=3.0.0 in c:\users\shahrukh khan\anaconda3\lib\site-packages (from mysql-connector-python) (3.20.1)

# %%
import mysql.connector as connection

try:
    mydb = connection.connect(host= "localhost",database = "LIC", user= "root",passwd="srk123",use_pure= True)
    #chech if the connection is established
    print(mydb.is_connected())
    
    query = "CREATE TABLE POLICY (POLICYid int(10) AUTO_INCREMENT PRIMARY KEY,FirstName VARCHAR (60),"\
    "LastName VARCHAR(60),RegistrationDate DATE,Class int(12),Section Varchar(10))"
    
    cursor= mydb.cursor() #create a cursor to execute  queries
    cursor.execute(query)
    print("(table Created!!")
    mydb.close()
except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# True
# 1050 (42S01): Table 'policy' already exists

# %%
mydb = connection.connect(host= "localhost",database = "LIC", user= "root",passwd="srk123",use_pure= True)

# %%
mydb.is_connected()
# Out:
# True

# %%
cur = mydb.cursor()
cur.execute("create table  pddetails (x1 int(5), x2 varchar(20),x3 Date)")
mydb.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\Users\SHAHRU~1\AppData\Local\Temp/ipykernel_14636/2775458190.py in <module>
# ----> 1 cur = mydb.cursor()
#       2 cur.execute("create table  pddetails (x1 int(5), x2 varchar(20),x3 Date)")
#       3 mydb.close()
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in cursor(self, buffered, raw, prepared, cursor_class, dictionary, named_tuple)
#    1278
#    1279         if not self.is_connected():
# -> 1280             raise errors.OperationalError("MySQL Connection not available.")
#    1281         if cursor_class is not None:
#    1282             if not issubclass(cursor_class, CursorBase):
#
# OperationalError: MySQL Connection not available.

# %%
import mysql.connector as connection

try:
    mydb = connection.connect(host= "localhost",database = "LIC", user = "root",passwd ="srk123",use_pure= True)
    #chech if the connection is established
    print(mydb.is_connected())
    
    query = "INSERT INTO POLICY VALUES('1132','SKKK','KHAN','1995-07-03','11', 'A')"
    
    cursor= mydb.cursor() #create a cursor to execute  queries
    cursor.execute(query)
    print("(values inserted into a table!!")
    mydb.close()
except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# True
# (values inserted into a table!!

# %%
mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\network.py in send_plain(self, buf, packet_number, compressed_packet_number)
#     160             try:
# --> 161                 self.sock.sendall(packet)
#     162             except IOError as err:
#
# ~\anaconda3\lib\ssl.py in sendall(self, data, flags)
#    1206         else:
# -> 1207             return super().sendall(data, flags)
#    1208
#
# OSError: [WinError 10038] An operation was attempted on something that is not a socket
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# C:\Users\SHAHRU~1\AppData\Local\Temp/ipykernel_14636/4062422964.py in <module>
# ----> 1 mydb.commit()
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in commit(self)
#    1321     def commit(self):
#    1322         """Commit current transaction"""
# -> 1323         self._execute_query("COMMIT")
#    1324
#    1325     def rollback(self):
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in _execute_query(self, query)
#    1340         """
#    1341         self.handle_unread_result()
# -> 1342         self.cmd_query(query)
#    1343
#    1344     def info_query(self, query):
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     920         query = bytes(packet)
#     921         try:
# --> 922             result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     923         except errors.ProgrammingError as err:
#     924             if err.errno == 3948 and \
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in _send_cmd(self, command, argument, packet_number, packet, expect_response, compressed_packet_number)
#     567
#     568         try:
# --> 569             self._socket.send(
#     570                 self._protocol.make_command(command, packet or argument),
#     571                 packet_number, compressed_packet_number)
#
# ~\anaconda3\lib\site-packages\mysql\connector\network.py in send_plain(self, buf, packet_number, compressed_packet_number)
#     161                 self.sock.sendall(packet)
#     162             except IOError as err:
# --> 163                 raise errors.OperationalError(
#     164                     errno=2055, values=(self.get_address(), _strioerror(err)))
#     165             except AttributeError:
#
# OperationalError: 2055: Lost connection to MySQL server at 'localhost:3306', system error: 10038 An operation was attempted on something that is not a socket

# %%
mydb = connection.connect(host= "localhost",database = "LIC", user= "root",passwd="srk123",use_pure= True) #??????

# %%
cur = mydb.cursor()

# %%
cur.execute("insert into pddetails values(456,'ssks','2021-05-16')")#yyyy/mm/dd

# %%
mydb.commit()

# %%
cur.execute("insert into pddetails values(4568,'hdfss','2021-05-16')")#yyyy/mm/dd

# %%
import mysql.connector as connection

try:
    mydb = connection.connect(host= "localhost",database = "LIC", user = "root",passwd ="srk123",use_pure= True)
    #chech if the connection is established
    print(mydb.is_connected())
    
    query = "select * from pddetails"
    
    cursor= mydb.cursor() #create a cursor to execute  queries
    cursor.execute(query)
    for results in cursor.fetchall():
        print(results)
    mydb.close()# close the connection
    
except Exception as e:
    #mydb.close()
    print(str(e))
# Out:
# True
# (456, 'ssks', datetime.date(2021, 5, 16))
# (456, 'ssks', datetime.date(2021, 5, 16))
# (4568, 'hdfss', datetime.date(2021, 5, 16))
# (4568, 'hdfss', datetime.date(2021, 5, 16))
# (4568, 'hdfss', datetime.date(2021, 5, 16))
# (4568, 'hdfss', datetime.date(2021, 5, 16))
# (4568, 'hdfss', datetime.date(2021, 5, 16))
# (4568, 'hdfss', datetime.date(2021, 5, 16))
# (4568, 'hdfss', datetime.date(2021, 5, 16))
# (4568, 'hdfss', datetime.date(2021, 5, 16))
# (4568, 'hdfss', datetime.date(2021, 5, 16))
# (456, 'ssks', datetime.date(2021, 5, 16))
# (456, 'ssks', datetime.date(2021, 5, 16))
# (456, 'ssks', datetime.date(2021, 5, 16))
# (456, 'ssks', datetime.date(2021, 5, 16))

# %%
cur1 = mydb.cursor()
cur1.execute("select * from pddetails ")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\Users\SHAHRU~1\AppData\Local\Temp/ipykernel_14636/4193387381.py in <module>
# ----> 1 cur1 = mydb.cursor()
#       2 cur1.execute("select * from pddetails ")
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in cursor(self, buffered, raw, prepared, cursor_class, dictionary, named_tuple)
#    1278
#    1279         if not self.is_connected():
# -> 1280             raise errors.OperationalError("MySQL Connection not available.")
#    1281         if cursor_class is not None:
#    1282             if not issubclass(cursor_class, CursorBase):
#
# OperationalError: MySQL Connection not available.

# %%
for i in cur1.fetchall():
     print(i)

# %%
cur1 = mydb.cursor()
cur1.execute("select x1,x2 from pddetails ")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\Users\SHAHRU~1\AppData\Local\Temp/ipykernel_14636/2857786711.py in <module>
# ----> 1 cur1 = mydb.cursor()
#       2 cur1.execute("select x1,x2 from pddetails ")
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in cursor(self, buffered, raw, prepared, cursor_class, dictionary, named_tuple)
#    1278
#    1279         if not self.is_connected():
# -> 1280             raise errors.OperationalError("MySQL Connection not available.")
#    1281         if cursor_class is not None:
#    1282             if not issubclass(cursor_class, CursorBase):
#
# OperationalError: MySQL Connection not available.

# %%
for i in cur1.fetchall():
    print(i)

# %%
import pandas as pd

# %%
mydb

# %%
pd.read_sql(" select * from LIC.pddetails ")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\SHAHRU~1\AppData\Local\Temp/ipykernel_14636/1826284925.py in <module>
# ----> 1 pd.read_sql(" select * from LIC.pddetails ")
#
# TypeError: read_sql() missing 1 required positional argument: 'con'
