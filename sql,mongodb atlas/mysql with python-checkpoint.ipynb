# %%
! pip install pymysql

# %%
! pip install plotly

# %%
import pandas as pd
import seaborn as sn
import plotly.express as px
import numpy as np
import plotly.graph_objects as go
import math 
import pymysql
pd.set_option("display.max_column", None)

# %%
dbcon = pymysql.connect(host ="localhost",user = "root",password = "srk123",database = "titanic")

# %%
dbcon

# %%
pd.read_sql_query("""select * from titanic where survived""",dbcon,parse_dates = True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              2         1       1
# 1              3         1       3
# 2              4         1       1
# 3              9         1       3
# 4             10         1       2
# ..           ...       ...     ...
# 337          876         1       3
# 338          880         1       1
# 339          881         1       2
# 340          888         1       1
# 341          890         1       1
#
#                                                   Name     Sex  Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 1                               Heikkinen, Miss. Laina  female   26      0
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 3    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27      0
# 4                  Nasser, Mrs. Nicholas (Adele Achem)  female   14      1
# ..                                                 ...     ...  ...    ...
# ...

# %%
df = pd.read_sql_query("""select * from titanic where survived""",dbcon,parse_dates = True)
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            2         1       1
# 1            3         1       3
# 2            4         1       1
# 3            9         1       3
# 4           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 1                             Heikkinen, Miss. Laina  female   26      0
# 2       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27      0
# 4                Nasser, Mrs. Nicholas (Adele Achem)  female   14      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0          PC 17599  71.2833   C85        C
# 1      0  STON/O2. 3101282   7.9250              S
# 2      0            113803  53.1000  C123        S
# 3      2            347742  11.1333              S
# 4      0            237736  30.0708              C

# %%
df.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              2         1       1
# 1              3         1       3
# 2              4         1       1
# 3              9         1       3
# 4             10         1       2
# ..           ...       ...     ...
# 337          876         1       3
# 338          880         1       1
# 339          881         1       2
# 340          888         1       1
# 341          890         1       1
#
#                                                   Name     Sex  Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 1                               Heikkinen, Miss. Laina  female   26      0
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 3    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27      0
# 4                  Nasser, Mrs. Nicholas (Adele Achem)  female   14      1
# ...

# %%
df.describe()
# Out:
#        PassengerId  Survived      Pclass         Age       SibSp       Parch  \
# count   342.000000     342.0  342.000000  342.000000  342.000000  342.000000
# mean    444.368421       1.0    1.950292   24.035088    0.473684    0.464912
# std     252.358840       0.0    0.863321   17.122774    0.708688    0.771712
# min       2.000000       1.0    1.000000    0.000000    0.000000    0.000000
# 25%     250.750000       1.0    1.000000    7.250000    0.000000    0.000000
# 50%     439.500000       1.0    2.000000   25.000000    0.000000    0.000000
# 75%     651.500000       1.0    3.000000   35.000000    1.000000    1.000000
# max     890.000000       1.0    3.000000   80.000000    4.000000    5.000000
#
#              Fare
# count  342.000000
# mean    48.395408
# std     66.596998
# min      0.000000
# 25%     12.475000
# 50%     26.000000
# 75%     57.000000
# max    512.329200

# %%
sns.countplot(x= "survived", data= df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SHAHRU~1\AppData\Local\Temp/ipykernel_17068/1710521606.py in <module>
# ----> 1 sns.countplot(x= "survived", data= df)
#
# NameError: name 'sns' is not defined

# %%
# !pip install sns
# Out:
# ...
#   Created wheel for sns: filename=sns-0.1-py3-none-any.whl size=2661 sha256=66cfd541a90392ad60a1c261075266b1f24f41ee8846405311c933b2c936fd70
#   Stored in directory: c:\users\shahrukh khan\appdata\local\pip\cache\wheels\ff\12\fa\4d724fdfed493cfe12b239ae9a0bc26b2fd85bb7dc9ecde7c3
# Successfully built sns
# ...

# %%
sns.countplot(x= "survived", data= df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SHAHRU~1\AppData\Local\Temp/ipykernel_17068/1710521606.py in <module>
# ----> 1 sns.countplot(x= "survived", data= df)
#
# NameError: name 'sns' is not defined
